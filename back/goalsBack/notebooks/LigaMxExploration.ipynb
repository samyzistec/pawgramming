# %%
#import packages
from statsbombpy import sb
import pandas as pd
from mplsoccer import VerticalPitch,Pitch
from highlight_text import ax_text, fig_text
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import seaborn as sns

# %%
email = "itam_hackathon@hudl.com"
password = "pGwIprel"

# %%
competitions = sb.competitions(creds={"user":email, "passwd": password})

# %%
competitions
# Out:
#    competition_id  season_id country_name competition_name competition_gender  \
# 0              73        317       Mexico          Liga MX               male
# 1              73        281       Mexico          Liga MX               male
# 2              73        235       Mexico          Liga MX               male
# 3              73        108       Mexico          Liga MX               male
#
#    competition_youth  competition_international season_name  \
# 0              False                      False   2024/2025
# 1              False                      False   2023/2024
# 2              False                      False   2022/2023
# 3              False                      False   2021/2022
#
#                 match_updated           match_updated_360  \
# 0  2025-08-30T16:14:20.970616  2025-08-30T16:14:20.970616
# 1  2024-12-20T23:40:31.103974  2024-12-20T23:40:31.103974
# 2  2024-09-28T11:05:11.667984  2024-09-28T11:05:11.667984
# ...

# %%
comp_id = 73
season_id = 281

# %%
matches = sb.matches(competition_id=comp_id, season_id=season_id, creds={"user": email, "passwd": password})

# %%
matches
# Out:
#      match_id  match_date      kick_off       competition     season  \
# 0     3889704  2023-09-17  18:00:00.000  Mexico - Liga MX  2023/2024
# 1     3889639  2023-07-01  03:00:00.000  Mexico - Liga MX  2023/2024
# 2     3889750  2023-10-25  01:00:00.000  Mexico - Liga MX  2023/2024
# 3     3889645  2023-07-04  02:00:00.000  Mexico - Liga MX  2023/2024
# 4     3919031  2024-03-02  01:00:00.000  Mexico - Liga MX  2023/2024
# ..        ...         ...           ...               ...        ...
# 335   3889723  2023-09-30  23:00:00.000  Mexico - Liga MX  2023/2024
# 336   3918959  2024-01-18  01:00:00.000  Mexico - Liga MX  2023/2024
# 337   3918976  2024-01-27  23:00:00.000  Mexico - Liga MX  2023/2024
# 338   3919043  2024-03-10  01:00:00.000  Mexico - Liga MX  2023/2024
# 339   3919069  2024-04-07  03:05:00.000  Mexico - Liga MX  2023/2024
#
#              home_team          away_team  home_score  away_score attendance  \
# ...

# %%
match = matches[matches["match_id"] == 3889702]

# %%
match
# Out:
#     match_id  match_date      kick_off       competition     season home_team  \
# 61   3889702  2023-09-17  03:10:00.000  Mexico - Liga MX  2023/2024   América
#
#       away_team  home_score  away_score attendance  ...  \
# 61  Guadalajara           4           0       None  ...
#
#               last_updated_360  match_week competition_stage         stadium  \
# 61  2023-10-29T02:09:54.488951           8          Apertura  Estadio Azteca
#
#                       referee         home_managers    away_managers  \
# 61  Fernando Guerrero Ramírez  André Soares Jardine  Veljko Paunovic
#
#    data_version  shot_fidelity_version xy_fidelity_version
# 61        1.1.0                      2                   2
#
# [1 rows x 27 columns]

# %%
match_id = match["match_id"].iloc[0]
print(match_id)
# Out:
# 3889702

# %%
events = sb.events(match_id=match["match_id"].iloc[0], creds={"user": email, "passwd": password})
# Out:
# /Users/omaratriano/Documents/TecNM/Local Segundo Semestre/Pawgrammers/back/goalsBack/.venv/lib/python3.12/site-packages/statsbombpy/sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)

# %%
events
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome  \
# 0      NaN                NaN                  NaN
# 1      NaN                NaN                  NaN
# 2      NaN                NaN                  NaN
# 3      NaN                NaN                  NaN
# 4      NaN                NaN                  NaN
# ...    ...                ...                  ...
# 3341   NaN        Yellow Card                  NaN
# 3342   NaN        Yellow Card                  NaN
# 3343   NaN                NaN                  NaN
# 3344   NaN                NaN                  NaN
# 3345   NaN                NaN                  NaN
#
#      ball_recovery_recovery_failure block_deflection block_save_block  \
# 0                               NaN              NaN              NaN
# 1                               NaN              NaN              NaN
# 2                               NaN              NaN              NaN
# ...

# %%
#Evento gol esquina: 3308

# %%
for col in events.columns:
    print(col)
# Out:
# 50_50
# bad_behaviour_card
# ball_receipt_outcome
# ball_recovery_recovery_failure
# block_deflection
# block_save_block
# carry_end_location
# clearance_aerial_won
# clearance_body_part
# clearance_head
# clearance_left_foot
# clearance_right_foot
# counterpress
# dribble_nutmeg
# dribble_outcome
# duel_outcome
# duel_type
# duration
# foul_committed_advantage
# foul_committed_card
# foul_won_advantage
# foul_won_defensive
# goalkeeper_body_part
# goalkeeper_end_location
# goalkeeper_outcome
# goalkeeper_position
# goalkeeper_punched_out
# goalkeeper_technique
# goalkeeper_type
# id
# index
# injury_stoppage_in_chain
# interception_outcome
# location
# match_id
# minute
# miscontrol_aerial_won
# obv_against_after
# obv_against_before
# obv_against_net
# obv_for_after
# obv_for_before
# obv_for_net
# obv_total_net
# off_camera
# out
# pass_aerial_won
# pass_angle
# pass_assisted_shot_id
# pass_body_part
# pass_cross
# pass_cut_back
# pass_deflected
# pass_end_location
# ...

# %%
play_pattern_corners = events[events["play_pattern"] == "From Corner"]

# %%
play_pattern_corners
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome  \
# 33     NaN                NaN                  NaN
# 34     NaN                NaN                  NaN
# 493    NaN                NaN                  NaN
# 494    NaN                NaN                  NaN
# 631    NaN                NaN                  NaN
# ...    ...                ...                  ...
# 3241   NaN                NaN                  NaN
# 3243   NaN                NaN                  NaN
# 3307   NaN                NaN                  NaN
# 3308   NaN                NaN                  NaN
# 3332   NaN                NaN                  NaN
#
#      ball_recovery_recovery_failure block_deflection block_save_block  \
# 33                              NaN              NaN              NaN
# 34                              NaN              NaN              NaN
# 493                             NaN              NaN              NaN
# ...

# %%
pass_type_corners = events[events["pass_type"]=="Corner"]

# %%
pass_type_corners
# Out:
#     50_50 bad_behaviour_card ball_receipt_outcome  \
# 33    NaN                NaN                  NaN
# 493   NaN                NaN                  NaN
# 631   NaN                NaN                  NaN
# 664   NaN                NaN                  NaN
# 676   NaN                NaN                  NaN
# 694   NaN                NaN                  NaN
# 696   NaN                NaN                  NaN
# 864   NaN                NaN                  NaN
# 895   NaN                NaN                  NaN
# 923   NaN                NaN                  NaN
#
#     ball_recovery_recovery_failure block_deflection block_save_block  \
# 33                             NaN              NaN              NaN
# 493                            NaN              NaN              NaN
# 631                            NaN              NaN              NaN
# 664                            NaN              NaN              NaN
# ...
